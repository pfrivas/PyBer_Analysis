# %%
import matplotlib.pyplot as plt

# %%
x = [50, 42, 39, 34, 32, 48, 22, 17, 8, 13]
y = [17, 19, 21, 22, 24, 23, 34, 31, 43, 35]

# %%
plt.scatter(x,y, c='green', marker = 'x', s=x)
plt.xlabel('Total Number of Rides (Per City)')
plt.ylabel('Average Fare ($)')
plt.title('Average Fare vs Total Rides')
plt.show()

# %%
# Scatter plots have many benefits over line and bar charts. 
    # A scatter plot visually depicts a positive, negative, or no-correlation relationship between two factors.

# In the following scatter plot, 
    # we determine that there is no correlation between the number of rides and the average fare, 
        # because the r value is positive and close to zero. 
        # This is called a regression analysis.
